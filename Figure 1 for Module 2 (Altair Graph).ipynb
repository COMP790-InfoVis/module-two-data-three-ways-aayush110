# %%
import pandas as pd

data = pd.read_csv("los angeles 2023-01-01 to 2023-03-01 copy.csv")
data.head()
# Out:
#           name    datetime  tempmax  tempmin  temp  feelslikemax  \
# 0  los angeles  2023-01-01     16.3     10.4  13.4          16.3
# 1  los angeles  2023-01-02     14.2      9.1  11.8          14.2
# 2  los angeles  2023-01-03     14.9     10.0  12.8          14.9
# 3  los angeles  2023-01-04     16.3     13.9  15.0          16.3
# 4  los angeles  2023-01-05     17.2     11.2  14.2          17.2
#
#    feelslikemin  feelslike   dew  humidity  ...  solarenergy  uvindex  \
# 0          10.4       13.4   8.4      73.2  ...          3.9        2
# 1           9.1       11.8   5.0      63.7  ...          3.0        2
# 2          10.0       12.8  10.3      84.8  ...          4.2        3
# 3          13.9       15.0  13.9      93.1  ...          2.2        2
# 4          11.2       14.2  11.7      85.3  ...          3.8        3
#
#    severerisk              sunrise               sunset  moonphase  \
# 0          10  2023-01-01T06:58:43  2023-01-01T16:54:38       0.32
# ...

# %%
import altair as alt

interval = alt.selection_interval(encodings=['y'])

alt.Chart(data).mark_point().encode(
    x='temp:Q',
    y='windspeed:Q',
    color=alt.condition(interval, 'datetime', alt.value('lightgray'))
).add_selection(
    interval
)
# Out:
# alt.Chart(...)

# %%
import altair as alt

interval = alt.selection_interval(encodings=['y'])

alt.Chart(data).mark_point().encode(
    x='temp:Q',
    y='windspeed:Q',
    color=alt.condition(interval, 'datetime', alt.value('lightgray'))
).add_selection(
    interval
)
# Out:
# alt.Chart(...)

# %%
import altair as alt

interval = alt.selection_interval(encodings=['y'])

alt.Chart(data).mark_point().encode(
    x='temp:Q',
    y='windspeed:Q',
    color=alt.condition(interval, 'datetime', alt.value('lightgray'))
).add_selection(
    interval
)
# Out:
# alt.Chart(...)

# %%
click = alt.selection_multi(encodings=['color'])

scatter = alt.Chart(data).mark_point().encode(
    x='temp:Q',
    y='windspeed:Q',
    color='datetime:N'
).transform_filter(
    click
)

hist = alt.Chart(data).mark_bar().encode(
    x='temp',
    y='datetime',
    color=alt.condition(click, 'datetime', alt.value('lightgray'))
).add_selection(
    click
)

scatter & hist
# Out:
# alt.VConcatChart(...)
